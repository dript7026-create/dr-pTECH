# %% [markdown]
# # drIpTECH Jupyter + PowerShell Notification Setup
# This notebook uses the `drIpTECH (.venv)` kernel (created in the workspace) and shows examples of invoking PowerShell notifications securely from Python.
# **Security note:** the examples call local PowerShell only and do not download or execute remote code. Review `readAIpolish/ps_notify.ps1` before running.

# %%
# Example: run a local PowerShell function to show a notification (message box fallback)
# Example: run the signed PowerShell via the Python wrapper (requires typing 'I CONSENT')
import subprocess, sys
cmd = [sys.executable, 'scripts\ps_notify.py', 'drIpTECH', 'Hello from Python via PowerShell']
print('Running:', ' '.join(cmd))
res = subprocess.run(cmd, capture_output=True, text=True)
print('returncode:', res.returncode)
print('stdout:', res.stdout)
print('stderr:', res.stderr)
